# %%
# !git clone https://github.com/CRIPAC-DIG/GRACE.git
# %cd GRACE
# Out:
# Cloning into 'GRACE'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 45 (delta 14), reused 7 (delta 7), pack-reused 20 (from 1)
# Receiving objects: 100% (45/45), 124.04 KiB | 5.39 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# /content/GRACE

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install torch-geometric
# !pip install pandas pyyaml scikit-learn
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.8 MB/s eta 0:00:00
# ...

# %%
# !python run_grace_temporal.py \
  --csv visit_matrix_large_depr_z_1.csv \
  --weights weights.csv \
  --history 7 \
  --device cuda
# Out:
# Using device: cuda
# Loaded data: 10 nodes, 740 days
# Loaded weighted adjacency matrix
# Train windows: 513
# Test windows:  220
# [GRACE] Epoch 50/200 | Loss: 1513.0790
# [GRACE] Epoch 100/200 | Loss: 1475.9633
# [GRACE] Epoch 150/200 | Loss: 1445.1721
# [GRACE] Epoch 200/200 | Loss: 1427.3378
# [REG] Epoch 20/100 | Loss: 179.6013
# [REG] Epoch 40/100 | Loss: 172.7176
# [REG] Epoch 60/100 | Loss: 167.7365
# [REG] Epoch 80/100 | Loss: 166.6701
# [REG] Epoch 100/100 | Loss: 165.1070
#
# ...
# FINAL BENCHMARK RESULT
# Test MSE: 0.519320
# ...
